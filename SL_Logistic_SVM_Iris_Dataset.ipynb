# %%
import pandas as pd
from sklearn.datasets import load_iris
iris_dataset = load_iris()
iris_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
df = pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)
# df = pd.DataFrame(iris_dataset['data'])
# df.columns = iris_dataset['feature_names']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['target'] = iris_dataset.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
# df.head(4)
# df.sample(4)
# df.tail(4)
df['target'].unique()
# Out:
# array([0, 1, 2])

# %%
# Is there any invalid values
  ## 1. All features shd contain only numbers
  ## 2. Target contains only Integer
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.corr() # Correlation between attributes
# Out:
#                    sepal length (cm)  ...    target
# sepal length (cm)           1.000000  ...  0.782561
# sepal width (cm)           -0.117570  ... -0.426658
# petal length (cm)           0.871754  ...  0.949035
# petal width (cm)            0.817941  ...  0.956547
# target                      0.782561  ...  1.000000
#
# [5 rows x 5 columns]

# %%
X = df[['sepal length (cm)','petal length (cm)','petal width (cm)']]  # Take the corresponding 3 features of highest 3 Target values 
y = df['target']

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X,y)
model.score(X,y)*100
# Out:
# 96.66666666666667

# %%
# Error Matrix
from sklearn.metrics import confusion_matrix
X.head(2)
# Out:
#    sepal length (cm)  petal length (cm)  petal width (cm)
# 0                5.1                1.4               0.2
# 1                4.9                1.4               0.2

# %%
y_predict = model.predict(X)
y_predict.shape
# Out:
# (150,)

# %%
y_predict = model.predict(X)
confusion_matrix(y,y_predict)
# Out:
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0,  2, 48]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_predict)*100
# Out:
# 96.66666666666667

# %%
## SVM - Support Vector Machine

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()
iris_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
import pandas as pd
df = pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)
# df = pd.DataFrame(iris_dataset['data'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target']=iris_dataset.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
df.corr()
# Out:
#                    sepal length (cm)  ...    target
# sepal length (cm)           1.000000  ...  0.782561
# sepal width (cm)           -0.117570  ... -0.426658
# petal length (cm)           0.871754  ...  0.949035
# petal width (cm)            0.817941  ...  0.956547
# target                      0.782561  ...  1.000000
#
# [5 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.shape
# Out:
# (150, 5)

# %%
X = df.drop('target',axis=1)
y = df['target']

# %%
from sklearn.svm import SVC # Support Vector Classifier
model = SVC(kernel='rbf')
model.fit(X,y)
model.score(X,y)
y_predict = model.predict(X)
from sklearn.metrics import accuracy_score
accuracy_score(y,y_predict)
# Out:
# 0.9733333333333334

# %%
from sklearn.metrics import confusion_matrix
y_predict = model.predict(X)
confusion_matrix(y,y_predict)
# Out:
# array([[50,  0,  0],
#        [ 0, 48,  2],
#        [ 0,  2, 48]])
