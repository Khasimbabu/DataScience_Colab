# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv('/content/sample_data/college_1.csv')
df2 = pd.read_csv('/content/sample_data/college_2.csv')
print(df1.head())
print(df2.head())
# Out:
#           Name  python  ...                        Department  Rising
# 0    A.Dharani    82.0  ...  Computer Science and Engineering       0
# 1  V.JEEVITHA     82.0  ...  Computer Science and Engineering       0
# 2  HEMAVATHI.R   100.0  ...  Computer Science and Engineering       0
# 3  Mugunthan S   100.0  ...  Computer Science and Engineering       0
# 4  Sathammai.S   100.0  ...  Computer Science and Engineering       0
#
# [5 rows x 7 columns]
#                 Name  python  ...                                 Department  Rising
# 0      ASHOK KUMAR K     100  ...     Electronics and Electrical Engineering       0
# 1            Chandru       0  ...           Computer Science and Engineering     340
# 2  Ganesh Ramkumar R      -1  ...           Computer Science and Engineering    2000
# 3    Bodipudi Harini      -1  ...  Electronics and Communication Engineering       0
# 4          VIINU V P      -1  ...     Electronics and Electrical Engineering       0
#
# ...

# %%
#df3 = df1.merge(df2, on='Department')
df3 = pd.merge(df1, df2, on='Name', how='outer')
df3
# df3.head()
# df3.shape
df3.to_csv("output.csv",index=False)
df3
# Out:
#               Name  ...  Rising_y
# 0        A.Dharani  ...       NaN
# 1      V.JEEVITHA   ...       NaN
# 2      HEMAVATHI.R  ...       NaN
# 3      Mugunthan S  ...       NaN
# 4      Sathammai.S  ...       NaN
# ..             ...  ...       ...
# 114  praveen raj j  ...       0.0
# 115     AMARNATH D  ...       0.0
# 116           bala  ...       0.0
# 117           XY Z  ...       0.0
# 118      Hariharan  ...       0.0
#
# [119 rows x 15 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df3_split1 = df3['CodeKata Score_x']>15000
df3_split1
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# Name: CodeKata Score_x, Length: 119, dtype: bool

# %%
# df3.isna().sum()
df3_split2 = [df3['CodeKata Score_x']<10000] and [df3['CodeKata Score_x']>15000]
df3_split2
# Out:
# [0       True
#  1       True
#  2       True
#  3      False
#  4      False
#         ...
#  114    False
#  115    False
#  116    False
#  117    False
#  118    False
#  Name: CodeKata Score_x, Length: 119, dtype: bool]

# %%
df3_split3 = [df3['CodeKata Score_x']<7000] and [df3['CodeKata Score_x']>10000]
df3_split3
# Out:
# [0       True
#  1       True
#  2       True
#  3       True
#  4      False
#         ...
#  114    False
#  115    False
#  116    False
#  117    False
#  118    False
#  Name: CodeKata Score_x, Length: 119, dtype: bool]

# %%
df3_split4 = df3['CodeKata Score_x']<7000
df3_split4
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# Name: CodeKata Score_x, Length: 119, dtype: bool

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df3_split4 = df3['CodeKata Score_x']>15000
df3_split4
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# Name: CodeKata Score_x, Length: 119, dtype: bool

# %% [markdown]
# ###### No of students participated

# %%
df3.keys()
# Out:
# Index(['Name', 'python_x', 'mysql_x', 'Previous Geekions_x',
#        'CodeKata Score_x', 'Department_x', 'Rising_x', 'python_y', 'python_en',
#        'mysql_y', 'computational_thinking', 'Previous Geekions_y',
#        'CodeKata Score_y', 'Department_y', 'Rising_y'],
#       dtype='object')

# %%
#df3['Name'].shape
# Out:
# (119,)

# %%
df3.sort_values("Name", inplace = True)
df3.drop_duplicates(subset ="Name", keep = False, inplace = True)
df3.shape
# Out:
# (119, 15)

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df3.describe()
# Out:
#          python_x    mysql_x  ...  CodeKata Score_y     Rising_y
# count   84.000000   84.00000  ...         35.000000    35.000000
# mean    73.392857   27.60119  ...       6801.428571   708.285714
# std     35.589280   36.30562  ...       3765.281134   836.429687
# min      0.000000    0.00000  ...          0.000000     0.000000
# 25%     52.250000    0.00000  ...       4630.000000     0.000000
# 50%     90.250000   11.62500  ...       7550.000000   380.000000
# 75%    100.000000   41.00000  ...       8240.000000  1350.000000
# max    100.000000  100.00000  ...      19400.000000  3140.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df3.sort_values(by="Rising_y",ascending=True, inplace = True)
df3.tail(3)
# Out:
#              Name  python_x  mysql_x  ...  CodeKata Score_y  Department_y Rising_y
# 51      Nivetha.S       0.0    50.00  ...               NaN           NaN      NaN
# 68    sivaranjini       0.0     3.75  ...               NaN           NaN      NaN
# 6   KALAIARASAN K      85.0    47.00  ...               NaN           NaN      NaN
#
# [3 rows x 15 columns]

# %%
df3.sort_values("Rising_y", inplace = True)
df3.head(3)
# Out:
#               Name  ...  Rising_y
# 117           XY Z  ...       0.0
# 108  P.GOVARDHANAN  ...       0.0
# 115     AMARNATH D  ...       0.0
#
# [3 rows x 15 columns]

# %%
df3['Rising_x']
# Out:
# 117      NaN
# 91       NaN
# 88       NaN
# 108      NaN
# 115      NaN
#        ...
# 7        0.0
# 24       0.0
# 51       0.0
# 68       0.0
# 6      130.0
# Name: Rising_x, Length: 119, dtype: float64

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df3.groupby(['Name','Previous Geekions_x'], as_index=False)['Previous Geekions_x'].max()
# Out:
#                   Name  Previous Geekions_x
# 0            A.Dharani              24500.0
# 1            ABIRAMI.S               1580.0
# 2   Abirami Anbazhagan               4320.0
# 3              Aravind                380.0
# 4                 Arun                 40.0
# ..                 ...                  ...
# 79             vignesh               1740.0
# 80           vignesh B                120.0
# 81         vijayakumar               1580.0
# 82        vikneshwaran                 40.0
# 83      yaser ahamed.A                  0.0
#
# [84 rows x 2 columns]

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
mydata=df3[['Department_x','CodeKata Score_x']]
mylabels='Department details', 'CodeKata Score details'
plt.pie(mydata,labels=mylabels,autopct='%1.1f%%')
plt.title('Department_x vs CodeKata Score_x')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-9af57fccdc31> in <module>()
#       3 mydata=df3[['Department_x','CodeKata Score_x']]
#       4 mylabels='Department details', 'CodeKata Score details'
# ----> 5 plt.pie(mydata,autopct='%1.1f%%')
#       6 plt.title('Department_x vs CodeKata Score_x')
#       7 plt.axis('equal')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df3.groupby(['Name','CodeKata Score_x'], as_index=False)['CodeKata Score_x'].max()
x = df3['Department_x']
y = df3['Name']
plt.bar(x='x',y='y',height='center',rot=70, title="Department wise toppers");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-9c6b5ddae865> in <module>()
#       2 x = df3['Department_x']
#       3 y = df3['Name']
# ----> 4 plt.bar(x='x',y='y',height='center',rot=70, title="Department wise toppers");
#       5 plot.show(block=True);
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...
